# %% [markdown]
# # Network Architecture Exploration: Understanding Underfitting and Overfitting
# ## Background
# This exercise aims to demonstrate how different neural network architectures can lead to underfitting or overfitting. You will experiment with various configurations of a fully connected neural network to observe these phenomena.
#
# ## Underfitting
# Occurs when a model is too simple to capture the underlying pattern of the data. Often caused by having too few layers or neurons.
#
# ## Overfitting
# Happens when a model learns the training data too well, including the noise, making it perform poorly on new, unseen data. This can result from having too many layers or neurons.

# %% [markdown]
# ## Setup
# Import the necessary libraries and prepare the dataset.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# Generate synthetic data
X, y = make_circles(n_samples=6000, noise=0.09, factor=0.5, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()

# %% [markdown]
# # Model Building
# Define a function to create a model with a variable number of layers and neurons.

# %%
def build_model(num_layers=1, num_neurons=10, activation_function='sigmoid'):
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function, input_shape=(2,)))
    
    for _ in range(num_layers - 1):
        model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function))
        
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model.count_params()
# Out:
# 151

# %% [markdown]
# # Train and Evaluate Model Script
# Below is a skeleton for a function to train and evaluate your models. Fill in the missing parts as indicated by the comments.

# %%
def train_and_evaluate_model(model, epochs=50, plot=True):
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2)

    # Evaluate the model on the test set
    # TASK: Fill in the evaluation code here
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

    # Plotting (if enabled)
    if plot:
        # Plotting training history
        plt.figure(figsize=(18, 5))

        plt.subplot(1, 3, 1)
        plt.plot(history.history['accuracy'], label='Accuracy (training data)')
        plt.plot(history.history['val_accuracy'], label='Accuracy (validation data)')
        plt.title('Training and Validation Accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend()

        # Predicting on test data
        predictions = model.predict(X_test) > 0.5

        # Plotting model predictions
        plt.subplot(1, 3, 2)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm)
        plt.title('Model Predictions on Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        # Plotting ground truth
        plt.subplot(1, 3, 3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title('Ground Truth for Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        plt.show()

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f} \n")

    # TASK: Print or return any other metrics or plots you think are necessary

# Example of using the function with a specific architecture
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 1ms/step
# Test Loss: 0.4369
# Test Accuracy: 0.9387

# %% [markdown]
# # Experimentation
# ## Task 1: Underfitting
# 1. Create and train a model with very few layers and/or neurons (e.g., 1 layer with 5 neurons).
# 2. Evaluate Performance:
#     * Plot training and validation accuracy over epochs.
#     * Plot model predictions vs. ground truth on the test data.
#     * Analyze if the model's performance is poor on both training and test data, which indicates underfitting.

# %%
# Underfitting

model = build_model(num_layers=2, num_neurons=5)
train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 1ms/step
# Test Loss: 0.6848
# Test Accuracy: 0.5897

# %% [markdown]
# Reducing the neurons from 10 to 5 causes an underfit. The model is unable to capture the complexity in the underlaying data.
#
# ---

# %% [markdown]
# ## Task 2: Overfitting
# 1. Create a model with an excessive number of layers and/or neurons (e.g., 5 layers with 100 neurons each) and increased number of epochs.
# 2. Evaluate Performance:
#     * Observe the training and validation accuracy plots for a wide gap, indicating overfitting.
#     * Compare model predictions with ground truth for the test data.
#     * Look for high training accuracy but poor test accuracy.

# %%
# Overfitting by increasing epochs to the extreme

model = build_model(num_layers=2, num_neurons=5)
train_and_evaluate_model(model, epochs=5000)
# Out:
# 94/94 [==============================] - 0s 1ms/step
# Test Loss: 0.0127
# Test Accuracy: 0.9957

# %% [markdown]
# Increasing the epochs from 50 to 5000 not only causes a significantly longer training time, but also overfits the model, essentially training it on the noise, hindering its generalization to new, unseen data.
#
# ---

# %% [markdown]
# ## Task 3: Balanced Model
# 1. Experiment to find a balanced architecture.
# 2. Evaluate Performance:
#     * Ensure the training and validation accuracy are both high and close to each other.
#     * The model's predictions should closely match the ground truth for the test data.
#     * The model should not show signs of significant underfitting or overfitting.

# %%
model = build_model(num_layers=2, num_neurons=8)
train_and_evaluate_model(model, epochs=80)
# Out:
# 94/94 [==============================] - 0s 1ms/step
# Test Loss: 0.3337
# Test Accuracy: 0.9150

# %% [markdown]
# Let's try increasing the epochs.

# %%
model = build_model(num_layers=2, num_neurons=8)
train_and_evaluate_model(model, epochs=120)
# Out:
# 94/94 [==============================] - 1s 5ms/step
# Test Loss: 0.3780
# Test Accuracy: 0.8950

# %%
model = build_model(num_layers=2, num_neurons=8)
train_and_evaluate_model(model, epochs=160, plot=False)
# Out:
# Test Loss: 0.0183
# Test Accuracy: 0.9963

# %% [markdown]
# I'd say that's good enough.

# %% [markdown]
# # Evaluation and Analysis
# Use similar evaluation and visualization code as in the previous exercise to assess model performance.
# Answer questions like:
# 1. What signs of underfitting did you observe?
# 2. What were the indications of overfitting?
# 3. Describe the architecture of the balanced model and its performance.
#
# # Conclusion
# Reflect on the importance of matching model complexity with the problem complexity and discuss the trade-offs involved in designing neural network architectures.
#
# For this data, increasing epochs from the initial 50 seems to be the best way to improve model accuracy. However >160 epochs seem redundant.

# %% [markdown]
# ------------------

# %% [markdown]
# # Regularization Technique: Early Stopping
# ## Objective
# Understand how early stopping can be used as a regularization technique to prevent overfitting and improve the generalization of neural networks.
#
# ## Background
# Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method, such as gradient descent. It involves stopping the training process if the model's performance on a validation set starts to deteriorate, meaning the model begins to learn noise and details from the training data that negatively impact its performance on unseen data.
#
# ## How Early Stopping Works
# * Monitor the model's performance on a validation set during training.
# * If the performance on the validation set stops improving or starts to worsen, stop the training.
# * Often, a 'patience' parameter is set to allow some leeway, meaning training will stop only after the model's performance hasn't improved for a specified number of epochs.

# %% [markdown]
# # Implementation in TensorFlow
# TensorFlow provides an easy way to implement early stopping through callbacks. Here’s how you can add early stopping to your training process:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=True)

# Include this callback in the model's fit method
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3696 - accuracy: 0.9096 - val_loss: 0.3673 - val_accuracy: 0.9183
# Epoch 2/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.9258 - val_loss: 0.3467 - val_accuracy: 0.9383
# Epoch 3/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.9475 - val_loss: 0.3280 - val_accuracy: 0.9533
# Epoch 4/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3111 - accuracy: 0.9563 - val_loss: 0.3096 - val_accuracy: 0.9617
# Epoch 5/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.9633 - val_loss: 0.2898 - val_accuracy: 0.9733
# Epoch 6/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9725 - val_loss: 0.2719 - val_accuracy: 0.9767
# Epoch 7/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.9775 - val_loss: 0.2552 - val_accuracy: 0.9767
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2396 - accuracy: 0.9842 - val_loss: 0.2383 - val_accuracy: 0.9800
# Epoch 9/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2241 - accuracy: 0.9879 - val_loss: 0.2233 - val_accuracy: 0.9817
# Epoch 10/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2095 - accuracy: 0.9879 - val_loss: 0.2092 - val_accuracy: 0.9867
# Epoch 11/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9896 - val_loss: 0.1968 - val_accuracy: 0.9917
# Epoch 12/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1835 - accuracy: 0.9908 - val_loss: 0.1851 - val_accuracy: 0.9900
# Epoch 13/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1723 - accuracy: 0.9908 - val_loss: 0.1753 - val_accuracy: 0.9883
# Epoch 14/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9921 - val_loss: 0.1638 - val_accuracy: 0.9933
# Epoch 15/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9925 - val_loss: 0.1545 - val_accuracy: 0.9933
# Epoch 16/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1430 - accuracy: 0.9925 - val_loss: 0.1460 - val_accuracy: 0.9933
# Epoch 17/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9937 - val_loss: 0.1387 - val_accuracy: 0.9933
# Epoch 18/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1275 - accuracy: 0.9942 - val_loss: 0.1319 - val_accuracy: 0.9933
# Epoch 19/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.9937 - val_loss: 0.1246 - val_accuracy: 0.9917
# Epoch 20/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9946 - val_loss: 0.1191 - val_accuracy: 0.9917
# Epoch 21/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9946 - val_loss: 0.1133 - val_accuracy: 0.9933
# Epoch 22/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9946 - val_loss: 0.1076 - val_accuracy: 0.9917
# Epoch 23/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9937 - val_loss: 0.1041 - val_accuracy: 0.9933
# Epoch 24/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9946 - val_loss: 0.0989 - val_accuracy: 0.9917
# Epoch 25/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9946 - val_loss: 0.0946 - val_accuracy: 0.9917
# Epoch 26/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9950 - val_loss: 0.0908 - val_accuracy: 0.9917
# Epoch 27/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9946 - val_loss: 0.0873 - val_accuracy: 0.9917
# Epoch 28/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9950 - val_loss: 0.0844 - val_accuracy: 0.9933
# Epoch 29/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9946 - val_loss: 0.0808 - val_accuracy: 0.9917
# Epoch 30/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.9950 - val_loss: 0.0780 - val_accuracy: 0.9933
# Epoch 31/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9946 - val_loss: 0.0757 - val_accuracy: 0.9933
# Epoch 32/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9946 - val_loss: 0.0729 - val_accuracy: 0.9933
# Epoch 33/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9954 - val_loss: 0.0701 - val_accuracy: 0.9917
# Epoch 34/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9950 - val_loss: 0.0684 - val_accuracy: 0.9933
# Epoch 35/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9950 - val_loss: 0.0661 - val_accuracy: 0.9933
# Epoch 36/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9954 - val_loss: 0.0639 - val_accuracy: 0.9933
# Epoch 37/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9954 - val_loss: 0.0619 - val_accuracy: 0.9933
# Epoch 38/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9954 - val_loss: 0.0607 - val_accuracy: 0.9933
# Epoch 39/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9946 - val_loss: 0.0583 - val_accuracy: 0.9917
# Epoch 40/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9946 - val_loss: 0.0577 - val_accuracy: 0.9933
# Epoch 41/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 0.9954 - val_loss: 0.0554 - val_accuracy: 0.9933
# Epoch 42/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9954 - val_loss: 0.0542 - val_accuracy: 0.9933
# Epoch 43/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9950 - val_loss: 0.0531 - val_accuracy: 0.9933
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9954 - val_loss: 0.0517 - val_accuracy: 0.9933
# Epoch 45/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9954 - val_loss: 0.0504 - val_accuracy: 0.9933
# Epoch 46/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9950 - val_loss: 0.0494 - val_accuracy: 0.9933
# Epoch 47/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9950 - val_loss: 0.0483 - val_accuracy: 0.9933
# Epoch 48/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9950 - val_loss: 0.0468 - val_accuracy: 0.9917
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9950 - val_loss: 0.0460 - val_accuracy: 0.9933
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9946 - val_loss: 0.0449 - val_accuracy: 0.9933
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9950 - val_loss: 0.0444 - val_accuracy: 0.9933
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9950 - val_loss: 0.0431 - val_accuracy: 0.9933
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9950 - val_loss: 0.0425 - val_accuracy: 0.9933
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9946 - val_loss: 0.0420 - val_accuracy: 0.9933
# Epoch 55/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9954 - val_loss: 0.0412 - val_accuracy: 0.9933
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9954 - val_loss: 0.0403 - val_accuracy: 0.9933
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9962 - val_loss: 0.0391 - val_accuracy: 0.9933
# Epoch 58/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9950 - val_loss: 0.0387 - val_accuracy: 0.9933
# Epoch 59/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9954 - val_loss: 0.0379 - val_accuracy: 0.9933
# Epoch 60/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9946 - val_loss: 0.0375 - val_accuracy: 0.9933
# Epoch 61/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9958 - val_loss: 0.0370 - val_accuracy: 0.9933
# Epoch 62/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9954 - val_loss: 0.0364 - val_accuracy: 0.9933
# Epoch 63/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9954 - val_loss: 0.0355 - val_accuracy: 0.9933
# Epoch 64/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9954 - val_loss: 0.0352 - val_accuracy: 0.9933
# Epoch 65/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9954 - val_loss: 0.0344 - val_accuracy: 0.9933
# Epoch 66/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9962 - val_loss: 0.0340 - val_accuracy: 0.9933
# Epoch 67/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9954 - val_loss: 0.0335 - val_accuracy: 0.9933
# Epoch 68/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9950 - val_loss: 0.0334 - val_accuracy: 0.9933
# Epoch 69/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9962 - val_loss: 0.0330 - val_accuracy: 0.9933
# Epoch 70/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9946 - val_loss: 0.0324 - val_accuracy: 0.9933
# Epoch 71/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9954 - val_loss: 0.0319 - val_accuracy: 0.9933
# Epoch 72/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9954 - val_loss: 0.0316 - val_accuracy: 0.9933
# Epoch 73/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9958 - val_loss: 0.0315 - val_accuracy: 0.9933
# Epoch 74/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9962 - val_loss: 0.0306 - val_accuracy: 0.9933
# Epoch 75/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9958 - val_loss: 0.0302 - val_accuracy: 0.9933
# Epoch 76/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9962 - val_loss: 0.0298 - val_accuracy: 0.9933
# Epoch 77/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9954 - val_loss: 0.0295 - val_accuracy: 0.9933
# Epoch 78/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9962 - val_loss: 0.0294 - val_accuracy: 0.9933
# Epoch 79/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9958 - val_loss: 0.0290 - val_accuracy: 0.9933
# Epoch 80/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9958 - val_loss: 0.0287 - val_accuracy: 0.9933
# Epoch 81/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9958 - val_loss: 0.0283 - val_accuracy: 0.9933
# Epoch 82/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9962 - val_loss: 0.0286 - val_accuracy: 0.9933
# Epoch 83/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9971 - val_loss: 0.0276 - val_accuracy: 0.9933
# Epoch 84/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9962 - val_loss: 0.0275 - val_accuracy: 0.9933
# Epoch 85/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9967 - val_loss: 0.0272 - val_accuracy: 0.9933
# Epoch 86/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9962 - val_loss: 0.0272 - val_accuracy: 0.9933
# Epoch 87/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9958 - val_loss: 0.0278 - val_accuracy: 0.9933
# Epoch 88/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9971 - val_loss: 0.0265 - val_accuracy: 0.9933
# Epoch 89/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9962 - val_loss: 0.0263 - val_accuracy: 0.9933
# Epoch 90/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9962 - val_loss: 0.0261 - val_accuracy: 0.9933
# Epoch 91/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9971 - val_loss: 0.0257 - val_accuracy: 0.9933
# Epoch 92/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9962 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 93/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9962 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 94/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9962 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 95/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9975 - val_loss: 0.0249 - val_accuracy: 0.9933
# Epoch 96/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9971 - val_loss: 0.0247 - val_accuracy: 0.9933
# Epoch 97/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9962 - val_loss: 0.0247 - val_accuracy: 0.9933
# Epoch 98/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9971 - val_loss: 0.0245 - val_accuracy: 0.9933
# Epoch 99/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9962 - val_loss: 0.0243 - val_accuracy: 0.9933
# Epoch 100/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9971 - val_loss: 0.0243 - val_accuracy: 0.9933

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = build_model(num_layers=2, num_neurons=8)
train_and_evaluate_model(model, epochs=160, plot=False)

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=True)

# Include this callback in the model's fit method
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Test Loss: 0.0144
# Test Accuracy: 0.9977
#
# Epoch 1/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9979 - val_loss: 0.0210 - val_accuracy: 0.9967
# Epoch 2/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9979 - val_loss: 0.0212 - val_accuracy: 0.9967
# Epoch 3/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9979 - val_loss: 0.0204 - val_accuracy: 0.9967
# Epoch 4/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9979 - val_loss: 0.0202 - val_accuracy: 0.9967
# Epoch 5/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9979 - val_loss: 0.0197 - val_accuracy: 0.9967
# Epoch 6/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9979 - val_loss: 0.0195 - val_accuracy: 0.9967
# Epoch 7/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9979 - val_loss: 0.0197 - val_accuracy: 0.9967
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9979 - val_loss: 0.0199 - val_accuracy: 0.9967
# Epoch 9/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9979 - val_loss: 0.0192 - val_accuracy: 0.9967
# Epoch 10/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9979 - val_loss: 0.0188 - val_accuracy: 0.9967
# Epoch 11/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9979 - val_loss: 0.0186 - val_accuracy: 0.9967
# Epoch 12/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9983 - val_loss: 0.0190 - val_accuracy: 0.9967
# Epoch 13/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9979 - val_loss: 0.0184 - val_accuracy: 0.9967
# Epoch 14/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9979 - val_loss: 0.0187 - val_accuracy: 0.9967
# Epoch 15/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9979 - val_loss: 0.0178 - val_accuracy: 0.9967
# Epoch 16/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9979 - val_loss: 0.0177 - val_accuracy: 0.9967
# Epoch 17/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9979 - val_loss: 0.0180 - val_accuracy: 0.9967
# Epoch 18/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9979 - val_loss: 0.0176 - val_accuracy: 0.9967
# Epoch 19/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9979 - val_loss: 0.0185 - val_accuracy: 0.9967
# Epoch 20/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9983 - val_loss: 0.0178 - val_accuracy: 0.9967
# Epoch 21/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9983 - val_loss: 0.0174 - val_accuracy: 0.9967
# Epoch 22/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9979 - val_loss: 0.0168 - val_accuracy: 0.9967
# Epoch 23/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9979 - val_loss: 0.0172 - val_accuracy: 0.9967
# Epoch 24/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9979 - val_loss: 0.0172 - val_accuracy: 0.9967
# Epoch 25/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9979 - val_loss: 0.0169 - val_accuracy: 0.9967
# Epoch 26/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9979 - val_loss: 0.0175 - val_accuracy: 0.9967
# Epoch 27/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9983 - val_loss: 0.0165 - val_accuracy: 0.9967
# Epoch 28/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.0168 - val_accuracy: 0.9967
# Epoch 29/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9979 - val_loss: 0.0164 - val_accuracy: 0.9967
# Epoch 30/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9983 - val_loss: 0.0167 - val_accuracy: 0.9967
# Epoch 31/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.0164 - val_accuracy: 0.9967
# Epoch 32/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.0163 - val_accuracy: 0.9967
# Epoch 33/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9979 - val_loss: 0.0162 - val_accuracy: 0.9967
# Epoch 34/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.0161 - val_accuracy: 0.9967
# Epoch 35/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9979 - val_loss: 0.0156 - val_accuracy: 0.9967
# Epoch 36/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9979 - val_loss: 0.0158 - val_accuracy: 0.9967
# Epoch 37/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9979 - val_loss: 0.0162 - val_accuracy: 0.9967
# Epoch 38/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9983 - val_loss: 0.0159 - val_accuracy: 0.9967
# Epoch 39/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9979 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 40/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9979 - val_loss: 0.0157 - val_accuracy: 0.9967
# Epoch 41/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0153 - val_accuracy: 0.9967
# Epoch 42/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0158 - val_accuracy: 0.9967
# Epoch 43/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0156 - val_accuracy: 0.9967
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 45/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9979 - val_loss: 0.0152 - val_accuracy: 0.9967
# Epoch 46/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9979 - val_loss: 0.0148 - val_accuracy: 0.9967
# Epoch 47/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9979 - val_loss: 0.0149 - val_accuracy: 0.9967
# Epoch 48/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9979 - val_loss: 0.0157 - val_accuracy: 0.9967
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9967
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9979 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9967
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.0151 - val_accuracy: 0.9967
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9983 - val_loss: 0.0144 - val_accuracy: 0.9967
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.0147 - val_accuracy: 0.9967
# Epoch 55/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.0148 - val_accuracy: 0.9967
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9967
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9983 - val_loss: 0.0149 - val_accuracy: 0.9967
# Epoch 58/100
# 41/75 [===============>..............] - ETA: 0s - loss: 0.0169 - accuracy: 0.9954Restoring model weights from the end of the best epoch: 53.
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9975 - val_loss: 0.0146 - val_accuracy: 0.9967
# Epoch 58: early stopping

# %% [markdown]
# ## Task
# 1. Add early stopping to your neural network training process using the above code snippet.
# 2. Experiment with different values for the patience parameter and observe how it impacts the training process and the model's performance.
#
# ## Analysis and Questions
# * How does early stopping affect the number of epochs for which your model trains?
# * Did you observe any improvements in the generalization of your model to the test data?
# * How does the patience parameter impact the effectiveness of early stopping?
#
# ## Conclusion
# Reflect on the importance of regularization techniques like early stopping in preventing overfitting and improving model generalization.
